# %%
import matplotlib
#matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import math
import os
from pathlib import Path
import subprocess
from mpl_toolkits.basemap import Basemap, cm
import re

# %%
def convert_rep_to_level(intensity):
    '''
    https://www.data.jma.go.jp/add/suishin/catalogue/format/ObdObs001_format.pdf
    ※3 1kmメッシュ気象庁レーダー全国合成のレベル値(0~251)に沿って変換する
    '''
    intensity_level = np.zeros_like(intensity)
    intensity_level[intensity==9.999e+20] = 0  # レーダー外の値
    intensity_level[intensity==0.1] = 0
    intensity_level[intensity==260] = 255

    step_list = [0.1, 0.25, 0.5, 1.0, 2]
    block_first = [0.25, 2.13, 5.25, 10.5, 181]
    data_num = [18, 12, 10, 170, 38]

    for i, step in enumerate(step_list):
        rep = block_first[i] - step
        for i in list(range(data_num[i])):
            rep = round(rep + step, 2)
            mmh = round((rep*2-step)/2, 2)
            #print(rep, mmh)
            intensity_level[intensity==rep] = mmh
            
    return intensity_level

# %%
def  crop_latlon(intensity, city, d):
    # 緯度経度の設定
    grid_shape = (3360,2560)
    lat_step = (48-20) / grid_shape[0]
    lon_step = (150-118) / grid_shape[1]

    lats = np.zeros((grid_shape[0],1))
    lons = np.zeros((1,grid_shape[1]))

    for i in list(range(grid_shape[0])):
        lats[i][0] = 48 - i*lat_step
    for i in list(range(grid_shape[1])):
        lons[0][i] = 118 + i*lon_step

    lats = np.tile(lats, (1,grid_shape[1]))
    lons = np.tile(lons, (grid_shape[0],1))

    # 座標を指定，その周辺を切り取る
    n = np.where(lats[:,0]<city[0]+d)[0][0]
    s = np.where(city[0]-d<lats[:,0])[0][-1]
    e = np.where(city[1]-d<lons[0,:])[0][0]
    w = np.where(lons[0,:]<city[1]+d)[0][-1]
    #print(lats[:,0][n],lats[:,0][s],lons[0,:][e],lons[0,:][w])
    
    intensity_city = intensity[n:s,e:w]
    lats_city = lats[n:s,e:w]
    lons_city = lons[n:s,e:w]
    return intensity_city, lats_city, lons_city

# %%
def draw_map(intensity, city, d=2, base_color='black', cm=plt.cm.jet, savepath=None, coastline=False):
    # 切り出し
    intensity_city, lats_city, lons_city = crop_latlon(intensity, city, d)

    flat_lats_city = np.ravel(lats_city)
    flat_lons_city = np.ravel(lons_city)
    
    # 色指定
    coastline_color = 'white' if base_color == 'black' else 'black'
    zero_color = 0 if base_color == 'black' else 1

    # 色の変更
    cm = plt.cm.jet#jet
    cm_list = cm(np.arange(cm.N))
    cm_list[0,:3] = zero_color    # 0の値の色を変更
    mycmap = ListedColormap(cm_list)
    # 描画
    plt.figure()
    m = Basemap(llcrnrlat=lats_city.min(),urcrnrlat=lats_city.max(), \
                        llcrnrlon=lons_city.min(),urcrnrlon=lons_city.max())
                        #,resolution='l')  # 描画矩形座標を指定

    if coastline:
        m.drawcoastlines(color=coastline_color)  # 海岸線
    m.contourf(flat_lons_city, flat_lats_city, intensity_city,list(range(0,255)),latlon=True, tri=True, cmap=mycmap) 
    
    if savepath is not None:
        plt.savefig(savepath, transparent = True, bbox_inches = 'tight', pad_inches = 0, facecolor='black')
# Wall time: 5.87 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106024000.png
# Wall time: 5.78 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106025000.png
# Wall time: 5.71 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106030000.png
# Wall time: 5.89 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106031000.png
# Wall time: 5.73 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106032000.png
# Wall time: 5.8 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106033000.png
# Wall time: 5.69 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106034000.png
# Wall time: 6.01 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106035000.png
# Wall time: 5.88 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106040000.png
# Wall time: 5.84 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106041000.png
# Wall time: 5.72 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106042000.png
# Wall time: 5.93 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106043000.png
# Wall time: 5.86 s
# C:\Python36\lib\site-packages\matplotlib\pyplot.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106044000.png
# Wall time: 5.93 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106045000.png
# Wall time: 6.19 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106050000.png
# Wall time: 5.81 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106051000.png
# Wall time: 5.74 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106052000.png
# Wall time: 5.96 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106053000.png
# Wall time: 5.85 s
# saved:  Z:/B4_TakahiroKinoshita/develop/weather/data/kagoshima/img/20170106054000.png
# Wall time: 5.82 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-6-67f324a5964f> in bin2img(filepath, save, basepath)
#      19
#      20     if save:
# ---> 21         draw_map(intensity_level, kagoshima, d=2, base_color='black', savepath=savepath)
#      22     else:
#      23         draw_map(intensity_level, kagoshima, d=2, base_color='black')
#
# <ipython-input-5-04fa5bde2937> in draw_map(intensity, city, d, base_color, cm, savepath, coastline)
#      23     if coastline:
#      24         m.drawcoastlines(color=coastline_color)  # 海岸線
# ---> 25     m.contourf(flat_lons_city, flat_lats_city, intensity_city,list(range(0,255)),latlon=True, tri=True, cmap=mycmap)
#      26
#      27     if savepath is not None:
#
# C:\Python36\lib\site-packages\mpl_toolkits\basemap\__init__.py in with_transform(self, x, y, data, *args, **kwargs)
#     540             # convert lat/lon coords to map projection coords.
#     541             x, y = self(x,y)
# --> 542         return plotfunc(self,x,y,data,*args,**kwargs)
#     543     return with_transform
#     544
#
# C:\Python36\lib\site-packages\mpl_toolkits\basemap\__init__.py in contourf(self, x, y, data, *args, **kwargs)
#    3625                     CS = ax.tricontourf(triang,data,*args,**kwargs)
#    3626                 else:
# -> 3627                     CS = ax.tricontourf(x,y,data,*args,**kwargs)
#    3628             else:
#    3629                 # make sure x is monotonically increasing - if not,
#
# C:\Python36\lib\site-packages\matplotlib\axes\_axes.py in tricontourf(self, *args, **kwargs)
#    8077
#    8078     def tricontourf(self, *args, **kwargs):
# -> 8079         return mtri.tricontourf(self, *args, **kwargs)
#    8080     tricontourf.__doc__ = mtri.tricontour.__doc__
#    8081
#
# C:\Python36\lib\site-packages\matplotlib\tri\tricontour.py in tricontourf(ax, *args, **kwargs)
#     270 def tricontourf(ax, *args, **kwargs):
#     271     kwargs['filled'] = True
# --> 272     return TriContourSet(ax, *args, **kwargs)
#     273
#     274
#
# C:\Python36\lib\site-packages\matplotlib\tri\tricontour.py in __init__(self, ax, *args, **kwargs)
#      34         are described in the docstring of `tricontour`.
#      35         """
# ---> 36         ContourSet.__init__(self, ax, *args, **kwargs)
#      37
#      38     def _process_args(self, *args, **kwargs):
#
# C:\Python36\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     885         self._transform = kwargs.pop('transform', None)
#     886
# --> 887         kwargs = self._process_args(*args, **kwargs)
#     888         self._process_levels()
#     889
#
# C:\Python36\lib\site-packages\matplotlib\tri\tricontour.py in _process_args(self, *args, **kwargs)
#      45                 self.levels = args[0].levels
#      46         else:
# ---> 47             tri, z = self._contour_args(args, kwargs)
#      48             C = _tri.TriContourGenerator(tri.get_cpp_triangulation(), z)
#      49             self._mins = [tri.x.min(), tri.y.min()]
#
# C:\Python36\lib\site-packages\matplotlib\tri\tricontour.py in _contour_args(self, args, kwargs)
#      79             fn = 'contour'
#      80         tri, args, kwargs = Triangulation.get_from_args_and_kwargs(*args,
# ---> 81                                                                    **kwargs)
#      82         z = np.asarray(args[0])
#      83         if z.shape != tri.x.shape:
#
# C:\Python36\lib\site-packages\matplotlib\tri\triangulation.py in get_from_args_and_kwargs(*args, **kwargs)
#     165             mask = kwargs.pop('mask', None)
#     166
# --> 167             triangulation = Triangulation(x, y, triangles, mask)
#     168         return triangulation, args, kwargs
#     169
#
# C:\Python36\lib\site-packages\matplotlib\tri\triangulation.py in __init__(self, x, y, triangles, mask)
#      53             # No triangulation specified, so use matplotlib._qhull to obtain
#      54             # Delaunay triangulation.
# ---> 55             self.triangles, self._neighbors = _qhull.delaunay(x, y)
#      56             self.is_delaunay = True
#      57         else:
#
# KeyboardInterrupt:
