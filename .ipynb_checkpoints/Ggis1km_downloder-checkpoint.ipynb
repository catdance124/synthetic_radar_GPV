# %%
import os
import datetime
import subprocess
import re
import configparser

# %%
class Downloader:
    def __init__(self):
        self.tar_path = './tar'
        self.bin_path = '/mnt/hgfs/kagoshima/bin'  # Seminarをマウントしている
        subprocess.run(['mkdir', '-p', self.tar_path])
        subprocess.run(['mkdir', '-p', self.bin_path])
    
    def set_date(self, dt):
        # URLを指定
        directory = 'http://database.rish.kyoto-u.ac.jp/arch/jmadata/data/jma-radar/synthetic/original'
        date = dt.strftime('%Y/%m/%d')
        self.timestamp = dt.strftime('%Y%m%d%H%M%S')
        tar_filename = 'Z__C_RJTD_'+self.timestamp+'_RDR_JMAGPV__grib2.tar'
        self.URL = directory +'/'+ date +'/'+ tar_filename
        self.tar_file_path = self.tar_path + '/' + tar_filename
        self.bin_path_year = self.bin_path + '/' + dt.strftime('%Y')
        subprocess.run(['mkdir', '-p', self.bin_path_year])
        
    def get_bin_file(self):
        # binファイルがあるかを確認
        bin_file_path = self.bin_path_year+'/Z__C_RJTD_'+self.timestamp+'_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin'
        if os.path.exists(bin_file_path):
            print('already exist: ',bin_file_path)
        else:
            # tarファイルを~/tarに保存
            wget_result = subprocess.getstatusoutput('wget -nc -P '+self.tar_path+' '+self.URL)  # getstatusoutputは(exitcode, output)を返す
            if wget_result[0] != 0:  # ダウンロードエラーの場合
                error_detail = re.findall(r'エラー.*', wget_result[1])[0]
                self.out_error_URL('download', error_detail)
            else:
                # tarファイルから1kmメッシュデータのみを取り出す
                filelist = subprocess.getstatusoutput('tar -tf '+self.tar_file_path)[1].split('\n')  # tarファイル内ファイル名リスト
                ggis_name = [s for s in filelist if 'Ggis1km' in s]  # ファイル名を取得
                if ggis_name:  # リストが空でなければTrueを返す
                    ggis_name = ggis_name[0]
                    subprocess.run(['tar', '-C', self.bin_path_year, '-xvf', self.tar_file_path, ggis_name]) # tarファイルから/binに取り出す
                    subprocess.run(['rm', self.tar_file_path])  # tarファイルは不要なので削除
                    self.out_available(1)
                else:
                    self.out_error_URL('tarfile', 'no file')
                        
    def out_error_URL(self, error_type, error_detail):
        print(error_type+': '+self.URL)
        with open(self.bin_path+'/error_URL_'+self.timestamp[:4]+'.csv', 'a', encoding="utf_8_sig") as f:
            f.write(error_type+','+str(error_detail)+','+self.URL+'\n')
        self.out_available(0)
    
    def out_available(self, n):  # 1なら存在する，0なら存在しない
        with open(self.bin_path+'/available_'+self.timestamp[:4]+'.csv', 'a', encoding="utf_8_sig") as f:
            f.write(self.timestamp+','+str(n)+'\n')

# %%
if __name__ == '__main__':
    # 設定読み込み
    inifile = configparser.ConfigParser()
    inifile.read('./config.ini', 'UTF-8')

    start = inifile.get('period', 'start')
    end = inifile.get('period', 'end')
    num = inifile.get('interval', 'num')
    timescale = inifile.get('interval', 'timescale')

    dt = datetime.datetime.strptime(start, '%Y/%m/%d %H:%M:%S')
    dt_limit = datetime.datetime.strptime(end, '%Y/%m/%d %H:%M:%S')
    
    # インスタンスを作成しダウンロード開始
    downloader = Downloader()
    while dt < dt_limit:
        downloader.set_date(dt)
        downloader.get_bin_file()
        dt = dt + eval('datetime.timedelta(' + timescale + '=' + num + ')')
# Out:
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101000000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101001000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101002000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101003000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101004000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101005000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101010000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101011000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101012000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101013000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101014000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101015000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101020000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101021000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101022000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101023000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101024000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101025000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101030000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101031000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101032000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101033000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101034000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101035000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101040000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101041000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101042000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101043000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101044000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101045000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101050000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101051000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101052000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101053000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101054000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101055000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101060000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101061000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101062000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101063000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101064000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101065000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101070000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101071000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101072000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101073000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101074000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101075000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101080000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101081000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101082000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101083000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101084000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101085000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101090000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101091000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101092000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101093000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101094000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101095000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101100000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101101000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101102000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101103000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101104000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101105000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101110000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101111000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101112000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101113000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101114000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101115000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101120000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101121000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101122000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101123000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101124000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101125000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101130000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101131000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101132000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101133000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101134000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101135000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101140000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101141000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101142000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101143000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101144000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101145000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101150000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101151000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101152000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101153000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101154000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101155000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101160000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101161000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101162000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101163000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101164000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101165000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101170000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101171000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101172000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101173000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101174000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101175000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101180000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101181000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101182000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101183000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101184000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101185000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101190000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101191000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101192000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101193000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101194000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101195000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101200000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101201000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101202000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101203000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101204000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101205000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101210000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101211000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101212000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101213000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101214000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101215000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101220000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101221000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101222000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101223000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101224000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101225000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101230000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101231000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101232000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101233000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101234000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180101235000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102000000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102001000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102002000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102003000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102004000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102005000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102010000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102011000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102012000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102013000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102014000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102015000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102020000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102021000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102022000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102023000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102024000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102025000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102030000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102031000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102032000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102033000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102034000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102035000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102040000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102041000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102042000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102043000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102044000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102045000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102050000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102051000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102052000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102053000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102054000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102055000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102060000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102061000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102062000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102063000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102064000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102065000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102070000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102071000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102072000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102073000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102074000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102075000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102080000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102081000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102082000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102083000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102084000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102085000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102090000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102091000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102092000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102093000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102094000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102095000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102100000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102101000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102102000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102103000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102104000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102105000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102110000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102111000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102112000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102113000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102114000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102115000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102120000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102121000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102122000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102123000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102124000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102125000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102130000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102131000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102132000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102133000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102134000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102135000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102140000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102141000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102142000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102143000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102144000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102145000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102150000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102151000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102152000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102153000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102154000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102155000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102160000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102161000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102162000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102163000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102164000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102165000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102170000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102171000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102172000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102173000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102174000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102175000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102180000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102181000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102182000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102183000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102184000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102185000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102190000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102191000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102192000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102193000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102194000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102195000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102200000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102201000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102202000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102203000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102204000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102205000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102210000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102211000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102212000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102213000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102214000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102215000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102220000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102221000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102222000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102223000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# already exist:  /mnt/hgfs/kagoshima/bintest/2018/Z__C_RJTD_20180102224000_RDR_JMAGPV_Ggis1km_Prr10lv_ANAL_grib2.bin
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-ab9335f8ba4c> in <module>()
#      15     downloader = Downloader()
#      16     while dt < dt_limit:
# ---> 17         downloader.set_date(dt)
#      18         downloader.get_bin_file()
#      19         dt = dt + eval('datetime.timedelta(' + timescale + '=' + num + ')')
#
# <ipython-input-104-5ac694faee4f> in set_date(self, dt)
#      15         self.tar_file_path = self.tar_path + '/' + tar_filename
#      16         self.bin_path_year = self.bin_path + '/' + dt.strftime('%Y')
# ---> 17         subprocess.run(['mkdir', '-p', self.bin_path_year])
#      18
#      19     def get_bin_file(self):
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     451         kwargs['stderr'] = PIPE
#     452
# --> 453     with Popen(*popenargs, **kwargs) as process:
#     454         try:
#     455             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     754                                 c2pread, c2pwrite,
#     755                                 errread, errwrite,
# --> 756                                 restore_signals, start_new_session)
#     757         except:
#     758             # Cleanup if the child failed starting.
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1428                             errread, errwrite,
#    1429                             errpipe_read, errpipe_write,
# -> 1430                             restore_signals, start_new_session, preexec_fn)
#    1431                     self._child_created = True
#    1432                 finally:
#
# KeyboardInterrupt:
